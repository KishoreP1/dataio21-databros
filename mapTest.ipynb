# %%
import xarray as xr
import hvplot.dask  # noqa
import hvplot.xarray  # noqa
import cartopy.crs as ccrs
import dask.dataframe as dd
from scipy import stats

# %%
df = dd.read_csv('export_dataframe_summary.csv')
# df = df[df.endlongitude != 0]
df.head()
# Out:
#    configsversionstring  configversion  deltamediaversionstring  device  \
# 0                   NaN             14                      NaN  101701
# 1                   NaN              0                      NaN  101701
# 2                   NaN              0                      NaN  101701
# 3                   NaN              0                      NaN  100625
# 4                   NaN              0                      NaN  103940
#
#     endlatitude  endlocaltime   endlongitude  endodometer  filedate  \
# 0  5.830039e+09    -311497657  1.454342e+260   -168782097  20200610
# 1  0.000000e+00             0   0.000000e+00            0  20200624
# 2  0.000000e+00             0   0.000000e+00            0  20200602
# 3  4.006399e+01       6666905  -8.314288e+01        -1000  20200601
# 4  4.025804e+01       6624097  -8.338169e+01        -1000  20200601
#
#    filetimeutc  ...  startlatitude  startlocaltime startlongitude  \
# ...

# %%
df.hvplot.points('endlongitude', 'endlatitude', geo=True, color='red',c = 'state', alpha=0.2,
                 xlim = [-82,-78],ylim = [36,40],tiles=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\envs\dataio\lib\site-packages\IPython\core\formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ~\anaconda3\envs\dataio\lib\site-packages\holoviews\core\dimension.py in _repr_mimebundle_(self, include, exclude)
#    1314         combined and returned.
#    1315         """
# -> 1316         return Store.render(self)
#    1317
#    1318
#
# ~\anaconda3\envs\dataio\lib\site-packages\holoviews\core\options.py in render(cls, obj)
#    1403         data, metadata = {}, {}
#    1404         for hook in hooks:
# -> 1405             ret = hook(obj)
#    1406             if ret is None:
#    1407                 continue
#
# ...
